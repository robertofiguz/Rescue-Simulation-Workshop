# %%
# load proto files
import os
possible_components = ["wheel", "distance_sensor", "light_sensor", "camera", "lidar", "gps", "gyro", "accelerometer", "inertial_unit", "motor", "position_sensor", "touch_sensor", "brake", "connector", "emitter", "receiver", "speaker"]
# add path to proto files
path = "/Users/roberto/Projects/Rescue-Simulation-ORG/2024/MyAwesomeRobot.json"

# read proto file
with open(path, 'r') as f:
    proto = f.read()

# get webots sensor and actuator names
sensors = []
actuators = []
# convert file to list
proto = proto.splitlines()
for line in proto:
    print(line)
    if "name" in line:
        # get what is between quotes
        try:
            name = line.split('"')[1]
            #using regex check if name is a possible component
            for component in possible_components:
                if component in name:
                    print(name)
        except:
            continue
# Out:
# {
# 	"Distance Sensor 1": {
# 		"dictName": "Distance Sensor 1",
# 		"name": "Distance Sensor",
# 		"customName": "distance sensor1",
# 		"type": "",
# 		"x": -213,
# 		"y": 335,
# 		"z": -309,
# 		"rx": -0.58,
# 		"ry": 0.58,
# 		"rz": 0.58,
# 		"a": 2.09
# 	},
# 	"Distance Sensor 2": {
# 		"dictName": "Distance Sensor 2",
# 		"name": "Distance Sensor",
# 		"customName": "distance sensor2",
# 		"type": "",
# 		"x": -107,
# 		"y": 335,
# 		"z": -355,
# 		"rx": -0.58,
# 		"ry": 0.58,
# 		"rz": 0.58,
# 		"a": 2.09
# 	},
# 	"Distance Sensor 3": {
# 		"dictName": "Distance Sensor 3",
# 		"name": "Distance Sensor",
# 		"customName": "distance sensor3",
# 		"type": "",
# 		"x": 108,
# 		"y": 335,
# 		"z": -355,
# 		"rx": -0.58,
# 		"ry": 0.58,
# 		"rz": 0.58,
# 		"a": 2.09
# 	},
# 	"Distance Sensor 4": {
# 		"dictName": "Distance Sensor 4",
# 		"name": "Distance Sensor",
# 		"customName": "distance sensor4",
# 		"type": "",
# 		"x": 220,
# 		"y": 335,
# 		"z": -309,
# 		"rx": -0.58,
# ...
